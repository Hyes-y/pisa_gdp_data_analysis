# %% [markdown]
# ## PISA Score와 GDP 상관 관계 구하기

# %% [markdown]
# PISA, GDP (2018년 기준) 데이터로 분석할 예정입니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 선형 회귀,,
from sklearn import linear_model, datasets

# 내용 출력시 전체 보이도록
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')
# %matplotlib inline

# %% [markdown]
# ### 1. 2018년 GDP 구하기

# %%
data = pd.read_csv('gdp_per_capita.csv')
pisa_2018 = pd.read_csv('pisa_2018.csv')
gdp_data = data
gdp_2018_data = gdp_data.loc[:,['Country Name', 'Code', '2020']]
gdp_2018_data
# Out:
#                                           Country Name Code           2020
# 0                                                Aruba  ABW            NaN
# 1                          Africa Eastern and Southern  AFE    1359.618224
# 2                                          Afghanistan  AFG     516.747871
# 3                           Africa Western and Central  AFW    1710.073363
# 4                                               Angola  AGO    1776.166868
# 5                                              Albania  ALB    5246.292306
# 6                                              Andorra  AND            NaN
# 7                                           Arab World  ARB    5612.686570
# 8                                 United Arab Emirates  ARE   36284.555243
# 9                                            Argentina  ARG    8579.017773
# 10                                             Armenia  ARM    4266.018074
# 11                                      American Samoa  ASM   12844.900991
# 12                                 Antigua and Barbuda  ATG   13992.744480
# 13                                           Australia  AUS   51692.842748
# 14                                             Austria  AUT   48586.801321
# 15                                          Azerbaijan  AZE    4221.407478
# 16                                             Burundi  BDI     238.990726
# 17                                             Belgium  BEL   45159.348223
# 18                                               Benin  BEN    1291.040972
# 19                                        Burkina Faso  BFA     857.932730
# 20                                          Bangladesh  BGD    1961.613749
# 21                                            Bulgaria  BGR   10079.203381
# 22                                             Bahrain  BHR   20409.952805
# 23                                        Bahamas, The  BHS   25194.025144
# 24                              Bosnia and Herzegovina  BIH    6079.738285
# 25                                             Belarus  BLR    6424.152176
# 26                                              Belize  BLZ    4115.177008
# 27                                             Bermuda  BMU  107079.479837
# 28                                             Bolivia  BOL    3133.099803
# 29                                              Brazil  BRA    6796.844542
# 30                                            Barbados  BRB   15373.854704
# 31                                   Brunei Darussalam  BRN   27442.953828
# 32                                              Bhutan  BTN    3000.779327
# 33                                            Botswana  BWA    6404.899932
# 34                            Central African Republic  CAF     492.795871
# 35                                              Canada  CAN   43294.648163
# 36                      Central Europe and the Baltics  CEB   16168.196652
# 37                                         Switzerland  CHE   87097.036450
# 38                                     Channel Islands  CHI            NaN
# 39                                               Chile  CHL   13231.704207
# 40                                               China  CHN   10434.775187
# 41                                       Cote d'Ivoire  CIV    2325.723705
# 42                                            Cameroon  CMR    1537.130218
# 43                                    Congo, Dem. Rep.  COD     543.950393
# 44                                         Congo, Rep.  COG    1846.131297
# 45                                            Colombia  COL    5334.556042
# 46                                             Comoros  COM    1420.661747
# 47                                          Cabo Verde  CPV    3064.272388
# 48                                          Costa Rica  CRI   12140.854155
# 49                              Caribbean small states  CSS    8873.521929
# 50                                                Cuba  CUB    9477.852873
# 51                                             Curacao  CUW   16745.724314
# 52                                      Cayman Islands  CYM   85082.526856
# 53                                              Cyprus  CYP   27527.845306
# 54                                      Czech Republic  CZE   22931.274598
# 55                                             Germany  DEU   46208.429472
# 56                                            Djibouti  DJI    3425.484176
# 57                                            Dominica  DMA    7003.859021
# 58                                             Denmark  DNK   61063.316430
# 59                                  Dominican Republic  DOM    7268.196910
# 60                                             Algeria  DZA    3306.858208
# 61         East Asia & Pacific (excluding high income)  EAP    8254.670871
# 62                          Early-demographic dividend  EAR    3201.652532
# 63                                 East Asia & Pacific  EAS   11477.792592
# 64       Europe & Central Asia (excluding high income)  ECA    7668.524344
# 65                               Europe & Central Asia  ECS   23955.305158
# 66                                             Ecuador  ECU    5600.389615
# 67                                    Egypt, Arab Rep.  EGY    3569.206841
# 68                                           Euro area  EMU   37967.801866
# 69                                             Eritrea  ERI            NaN
# 70                                               Spain  ESP   27063.193918
# 71                                             Estonia  EST   23027.026996
# 72                                            Ethiopia  ETH     936.340461
# 73                                      European Union  EUU   34148.919900
# 74            Fragile and conflict affected situations  FCS    1622.216976
# 75                                             Finland  FIN   48744.988127
# 76                                                Fiji  FJI    5057.631913
# 77                                              France  FRA   39030.360371
# 78                                       Faroe Islands  FRO            NaN
# 79                               Micronesia, Fed. Sts.  FSM    3565.293294
# 80                                               Gabon  GAB    6881.715192
# 81                                      United Kingdom  GBR   41059.168809
# 82                                             Georgia  GEO    4266.690795
# 83                                               Ghana  GHA    2205.529016
# 84                                           Gibraltar  GIB            NaN
# 85                                              Guinea  GIN    1194.037865
# 86                                         Gambia, The  GMB     773.002070
# 87                                       Guinea-Bissau  GNB     727.520172
# 88                                   Equatorial Guinea  GNQ    7143.238705
# 89                                              Greece  GRC   17622.541003
# 90                                             Grenada  GRD    9261.551876
# 91                                           Greenland  GRL            NaN
# 92                                           Guatemala  GTM    4603.339617
# 93                                                Guam  GUM   34624.340129
# 94                                              Guyana  GUY    6955.939217
# 95                                         High income  HIC   44003.413710
# 96                                Hong Kong SAR, China  HKG   46323.863442
# 97                                            Honduras  HND    2389.012431
# 98              Heavily indebted poor countries (HIPC)  HPC     968.690500
# 99                                             Croatia  HRV   14134.162681
# 100                                              Haiti  HTI    1272.367992
# 101                                            Hungary  HUN   15980.740890
# 102                                          IBRD only  IBD    6149.361544
# 103                                   IDA & IBRD total  IBT    4891.090255
# 104                                          IDA total  IDA    1310.675160
# 105                                          IDA blend  IDB    1674.917871
# 106                                          Indonesia  IDN    3869.588427
# 107                                           IDA only  IDX    1126.932467
# 108                                        Isle of Man  IMN            NaN
# 109                                              India  IND    1927.707823
# 110                                     Not classified  INX            NaN
# 111                                            Ireland  IRL   85267.764744
# 112                                 Iran, Islamic Rep.  IRN    2422.480657
# 113                                               Iraq  IRQ    4145.862936
# 114                                            Iceland  ISL   59270.180051
# 115                                             Israel  ISR   44168.943636
# 116                                              Italy  ITA   31714.220947
# 117                                            Jamaica  JAM    4664.530242
# 118                                             Jordan  JOR    4282.765825
# 119                                              Japan  JPN   40193.252445
# 120                                         Kazakhstan  KAZ    9122.233430
# 121                                              Kenya  KEN    1878.580703
# 122                                    Kyrgyz Republic  KGZ    1173.611304
# 123                                           Cambodia  KHM    1543.669258
# 124                                           Kiribati  KIR    1653.540297
# 125                                St. Kitts and Nevis  KNA   18437.748924
# 126                                        Korea, Rep.  KOR   31631.469451
# 127                                             Kuwait  KWT   24811.769710
# 128  Latin America & Caribbean (excluding high income)  LAC    6779.199717
# 129                                            Lao PDR  LAO    2629.714583
# 130                                            Lebanon  LBN    4649.547646
# 131                                            Liberia  LBR     632.936386
# 132                                              Libya  LBY    3699.294765
# 133                                          St. Lucia  LCA    8804.561048
# 134                          Latin America & Caribbean  LCN    7244.659419
# 135       Least developed countries: UN classification  LDC    1053.752571
# 136                                         Low income  LIC     691.168333
# 137                                      Liechtenstein  LIE            NaN
# 138                                          Sri Lanka  LKA    3680.673477
# 139                                Lower middle income  LMC    2217.214884
# 140                                Low & middle income  LMY    4754.824100
# 141                                            Lesotho  LSO     875.353433
# 142                          Late-demographic dividend  LTE    9683.425159
# 143                                          Lithuania  LTU   20233.641348
# 144                                         Luxembourg  LUX  116014.602497
# 145                                             Latvia  LVA   17726.252935
# 146                                   Macao SAR, China  MAC   39403.135907
# 147                           St. Martin (French part)  MAF            NaN
# 148                                            Morocco  MAR    3058.691689
# 149                                             Monaco  MCO  173688.189360
# 150                                            Moldova  MDA    4547.059721
# 151                                         Madagascar  MDG     471.491496
# 152                                           Maldives  MDV    6924.105745
# 153                         Middle East & North Africa  MEA    6534.395623
# 154                                             Mexico  MEX    8329.271313
# 155                                   Marshall Islands  MHL    4129.850998
# 156                                      Middle income  MIC    5216.947891
# 157                                    North Macedonia  MKD    5917.262575
# 158                                               Mali  MLI     862.453019
# 159                                              Malta  MLT   27884.642827
# 160                                            Myanmar  MMR    1467.604281
# 161  Middle East & North Africa (excluding high inc...  MNA    3018.433655
# 162                                         Montenegro  MNE    7677.152226
# 163                                           Mongolia  MNG    4060.950518
# 164                           Northern Mariana Islands  MNP            NaN
# 165                                         Mozambique  MOZ     448.544281
# 166                                         Mauritania  MRT    1701.991163
# 167                                          Mauritius  MUS    8627.843157
# 168                                             Malawi  MWI     636.820537
# 169                                           Malaysia  MYS   10412.348983
# 170                                      North America  NAC   61502.095945
# 171                                            Namibia  NAM    4179.278066
# 172                                      New Caledonia  NCL            NaN
# 173                                              Niger  NER     567.669892
# 174                                            Nigeria  NGA    2097.092473
# 175                                          Nicaragua  NIC    1905.261152
# 176                                        Netherlands  NLD   52397.116713
# 177                                             Norway  NOR   67329.677791
# 178                                              Nepal  NPL    1155.142854
# 179                                              Nauru  NRU   10580.268188
# 180                                        New Zealand  NZL   41441.466667
# 181                                       OECD members  OED   38218.872374
# 182                                               Oman  OMN   14485.386116
# 183                                 Other small states  OSS   11766.973739
# 184                                           Pakistan  PAK    1188.859757
# 185                                             Panama  PAN   12509.835290
# 186                                               Peru  PER    6126.874540
# 187                                        Philippines  PHL    3298.829586
# 188                                              Palau  PLW   14243.864692
# 189                                   Papua New Guinea  PNG    2757.217530
# 190                                             Poland  POL   15720.994664
# 191                           Pre-demographic dividend  PRE    1332.049211
# 192                                        Puerto Rico  PRI   32290.921136
# 193                          Korea, Dem. People's Rep.  PRK            NaN
# 194                                           Portugal  PRT   22176.296712
# 195                                           Paraguay  PRY    5001.072760
# 196                                 West Bank and Gaza  PSE    3239.731108
# 197                        Pacific island small states  PSS    3768.543357
# 198                          Post-demographic dividend  PST   44475.189167
# 199                                   French Polynesia  PYF            NaN
# 200                                              Qatar  QAT   50124.385936
# 201                                            Romania  ROU   12896.088621
# 202                                 Russian Federation  RUS   10126.721794
# 203                                             Rwanda  RWA     797.855521
# 204                                         South Asia  SAS    1823.712912
# 205                                       Saudi Arabia  SAU   20110.316192
# 206                                              Sudan  SDN     486.418816
# 207                                            Senegal  SEN    1471.830962
# 208                                          Singapore  SGP   59797.752180
# 209                                    Solomon Islands  SLB    2250.601164
# 210                                       Sierra Leone  SLE     509.376594
# 211                                        El Salvador  SLV    3798.636521
# 212                                         San Marino  SMR            NaN
# 213                                            Somalia  SOM     438.255166
# 214                                             Serbia  SRB    7720.510572
# 215         Sub-Saharan Africa (excluding high income)  SSA    1500.349997
# 216                                        South Sudan  SSD            NaN
# 217                                 Sub-Saharan Africa  SSF    1501.152921
# 218                                       Small states  SST   10770.589778
# 219                              Sao Tome and Principe  STP    2157.840446
# 220                                           Suriname  SUR    4916.605666
# 221                                    Slovak Republic  SVK   19266.513574
# 222                                           Slovenia  SVN   25517.330665
# 223                                             Sweden  SWE   52274.408787
# 224                                           Eswatini  SWZ    3424.282212
# 225                          Sint Maarten (Dutch part)  SXM            NaN
# 226                                         Seychelles  SYC   10764.420422
# 227                               Syrian Arab Republic  SYR            NaN
# 228                           Turks and Caicos Islands  TCA   23879.926649
# 229                                               Chad  TCD     659.270045
# 230         East Asia & Pacific (IDA & IBRD countries)  TEA    8346.038810
# 231       Europe & Central Asia (IDA & IBRD countries)  TEC    8387.390693
# 232                                               Togo  TGO     914.950792
# 233                                           Thailand  THA    7186.874092
# 234                                         Tajikistan  TJK     859.137961
# 235                                       Turkmenistan  TKM            NaN
# 236  Latin America & the Caribbean (IDA & IBRD coun...  TLA    7035.753075
# 237                                        Timor-Leste  TLS    1442.730738
# 238  Middle East & North Africa (IDA & IBRD countries)  TMN    3015.703551
# 239                                              Tonga  TON    4624.823449
# 240                            South Asia (IDA & IBRD)  TSA    1823.712912
# 241          Sub-Saharan Africa (IDA & IBRD countries)  TSS    1501.152921
# 242                                Trinidad and Tobago  TTO   15425.635109
# 243                                            Tunisia  TUN    3521.591948
# 244                                             Turkey  TUR    8536.433320
# 245                                             Tuvalu  TUV    4143.109753
# 246                                           Tanzania  TZA    1076.469706
# 247                                             Uganda  UGA     822.027682
# 248                                            Ukraine  UKR    3724.938437
# 249                                Upper middle income  UMC    9177.840437
# 250                                            Uruguay  URY   15438.411666
# 251                                      United States  USA   63593.443621
# 252                                         Uzbekistan  UZB    1750.697113
# 253                     St. Vincent and the Grenadines  VCT    7278.016297
# 254                                      Venezuela, RB  VEN            NaN
# 255                             British Virgin Islands  VGB            NaN
# 256                              Virgin Islands (U.S.)  VIR            NaN
# 257                                            Vietnam  VNM    2785.724161
# 258                                            Vanuatu  VUT    2870.089300
# 259                                              World  WLD   10918.722834
# 260                                              Samoa  WSM    4067.843459
# 261                                             Kosovo  XKX    4346.637931
# 262                                        Yemen, Rep.  YEM            NaN
# 263                                       South Africa  ZAF    5655.867654
# 264                                             Zambia  ZMB     985.132436
# 265                                           Zimbabwe  ZWE    1214.509820

# %% [markdown]
# ### ✍ 데이터 전처리

# %%
# 불필요한 row 제거(값이 NaN인 경우)
gdp_2018_data = gdp_2018_data.dropna(axis=0)
gdp_2018_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 1 to 265
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  242 non-null    object
#  1   Code          242 non-null    object
#  2   2020          242 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 7.6+ KB

# %%
# 전처리 한 데이터에 컬럼을 붙여줍니다.

columns = ['나라', '나라코드', '1인당 GDP']
gdp_2018_data.columns = columns
gdp_2018_data.loc[31, '나라'] = 'Brunei'
gdp_2018_data.loc[96, '나라'] = 'Hong Kong'
gdp_2018_data.loc[146, '나라'] = 'Macau'
gdp_2018_data.loc[126, '나라'] = 'Republic of Korea'
gdp_2018_data.loc[221, '나라'] = 'Slovakia'
gdp_2018_data
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                                                     나라 나라코드        1인당 GDP
# 1                          Africa Eastern and Southern  AFE    1359.618224
# 2                                          Afghanistan  AFG     516.747871
# 3                           Africa Western and Central  AFW    1710.073363
# 4                                               Angola  AGO    1776.166868
# 5                                              Albania  ALB    5246.292306
# 7                                           Arab World  ARB    5612.686570
# 8                                 United Arab Emirates  ARE   36284.555243
# 9                                            Argentina  ARG    8579.017773
# 10                                             Armenia  ARM    4266.018074
# 11                                      American Samoa  ASM   12844.900991
# 12                                 Antigua and Barbuda  ATG   13992.744480
# 13                                           Australia  AUS   51692.842748
# 14                                             Austria  AUT   48586.801321
# 15                                          Azerbaijan  AZE    4221.407478
# 16                                             Burundi  BDI     238.990726
# 17                                             Belgium  BEL   45159.348223
# 18                                               Benin  BEN    1291.040972
# 19                                        Burkina Faso  BFA     857.932730
# 20                                          Bangladesh  BGD    1961.613749
# 21                                            Bulgaria  BGR   10079.203381
# 22                                             Bahrain  BHR   20409.952805
# 23                                        Bahamas, The  BHS   25194.025144
# 24                              Bosnia and Herzegovina  BIH    6079.738285
# 25                                             Belarus  BLR    6424.152176
# 26                                              Belize  BLZ    4115.177008
# 27                                             Bermuda  BMU  107079.479837
# 28                                             Bolivia  BOL    3133.099803
# 29                                              Brazil  BRA    6796.844542
# 30                                            Barbados  BRB   15373.854704
# 31                                              Brunei  BRN   27442.953828
# 32                                              Bhutan  BTN    3000.779327
# 33                                            Botswana  BWA    6404.899932
# 34                            Central African Republic  CAF     492.795871
# 35                                              Canada  CAN   43294.648163
# 36                      Central Europe and the Baltics  CEB   16168.196652
# 37                                         Switzerland  CHE   87097.036450
# 39                                               Chile  CHL   13231.704207
# 40                                               China  CHN   10434.775187
# 41                                       Cote d'Ivoire  CIV    2325.723705
# 42                                            Cameroon  CMR    1537.130218
# 43                                    Congo, Dem. Rep.  COD     543.950393
# 44                                         Congo, Rep.  COG    1846.131297
# 45                                            Colombia  COL    5334.556042
# 46                                             Comoros  COM    1420.661747
# 47                                          Cabo Verde  CPV    3064.272388
# 48                                          Costa Rica  CRI   12140.854155
# 49                              Caribbean small states  CSS    8873.521929
# 50                                                Cuba  CUB    9477.852873
# 51                                             Curacao  CUW   16745.724314
# 52                                      Cayman Islands  CYM   85082.526856
# 53                                              Cyprus  CYP   27527.845306
# 54                                      Czech Republic  CZE   22931.274598
# 55                                             Germany  DEU   46208.429472
# 56                                            Djibouti  DJI    3425.484176
# 57                                            Dominica  DMA    7003.859021
# 58                                             Denmark  DNK   61063.316430
# 59                                  Dominican Republic  DOM    7268.196910
# 60                                             Algeria  DZA    3306.858208
# 61         East Asia & Pacific (excluding high income)  EAP    8254.670871
# 62                          Early-demographic dividend  EAR    3201.652532
# 63                                 East Asia & Pacific  EAS   11477.792592
# 64       Europe & Central Asia (excluding high income)  ECA    7668.524344
# 65                               Europe & Central Asia  ECS   23955.305158
# 66                                             Ecuador  ECU    5600.389615
# 67                                    Egypt, Arab Rep.  EGY    3569.206841
# 68                                           Euro area  EMU   37967.801866
# 70                                               Spain  ESP   27063.193918
# 71                                             Estonia  EST   23027.026996
# 72                                            Ethiopia  ETH     936.340461
# 73                                      European Union  EUU   34148.919900
# 74            Fragile and conflict affected situations  FCS    1622.216976
# 75                                             Finland  FIN   48744.988127
# 76                                                Fiji  FJI    5057.631913
# 77                                              France  FRA   39030.360371
# 79                               Micronesia, Fed. Sts.  FSM    3565.293294
# 80                                               Gabon  GAB    6881.715192
# 81                                      United Kingdom  GBR   41059.168809
# 82                                             Georgia  GEO    4266.690795
# 83                                               Ghana  GHA    2205.529016
# 85                                              Guinea  GIN    1194.037865
# 86                                         Gambia, The  GMB     773.002070
# 87                                       Guinea-Bissau  GNB     727.520172
# 88                                   Equatorial Guinea  GNQ    7143.238705
# 89                                              Greece  GRC   17622.541003
# 90                                             Grenada  GRD    9261.551876
# 92                                           Guatemala  GTM    4603.339617
# 93                                                Guam  GUM   34624.340129
# 94                                              Guyana  GUY    6955.939217
# 95                                         High income  HIC   44003.413710
# 96                                           Hong Kong  HKG   46323.863442
# 97                                            Honduras  HND    2389.012431
# 98              Heavily indebted poor countries (HIPC)  HPC     968.690500
# 99                                             Croatia  HRV   14134.162681
# 100                                              Haiti  HTI    1272.367992
# 101                                            Hungary  HUN   15980.740890
# 102                                          IBRD only  IBD    6149.361544
# 103                                   IDA & IBRD total  IBT    4891.090255
# 104                                          IDA total  IDA    1310.675160
# 105                                          IDA blend  IDB    1674.917871
# 106                                          Indonesia  IDN    3869.588427
# 107                                           IDA only  IDX    1126.932467
# 109                                              India  IND    1927.707823
# 111                                            Ireland  IRL   85267.764744
# 112                                 Iran, Islamic Rep.  IRN    2422.480657
# 113                                               Iraq  IRQ    4145.862936
# 114                                            Iceland  ISL   59270.180051
# 115                                             Israel  ISR   44168.943636
# 116                                              Italy  ITA   31714.220947
# 117                                            Jamaica  JAM    4664.530242
# 118                                             Jordan  JOR    4282.765825
# 119                                              Japan  JPN   40193.252445
# 120                                         Kazakhstan  KAZ    9122.233430
# 121                                              Kenya  KEN    1878.580703
# 122                                    Kyrgyz Republic  KGZ    1173.611304
# 123                                           Cambodia  KHM    1543.669258
# 124                                           Kiribati  KIR    1653.540297
# 125                                St. Kitts and Nevis  KNA   18437.748924
# 126                                  Republic of Korea  KOR   31631.469451
# 127                                             Kuwait  KWT   24811.769710
# 128  Latin America & Caribbean (excluding high income)  LAC    6779.199717
# 129                                            Lao PDR  LAO    2629.714583
# 130                                            Lebanon  LBN    4649.547646
# 131                                            Liberia  LBR     632.936386
# 132                                              Libya  LBY    3699.294765
# 133                                          St. Lucia  LCA    8804.561048
# 134                          Latin America & Caribbean  LCN    7244.659419
# 135       Least developed countries: UN classification  LDC    1053.752571
# 136                                         Low income  LIC     691.168333
# 138                                          Sri Lanka  LKA    3680.673477
# 139                                Lower middle income  LMC    2217.214884
# 140                                Low & middle income  LMY    4754.824100
# 141                                            Lesotho  LSO     875.353433
# 142                          Late-demographic dividend  LTE    9683.425159
# 143                                          Lithuania  LTU   20233.641348
# 144                                         Luxembourg  LUX  116014.602497
# 145                                             Latvia  LVA   17726.252935
# 146                                              Macau  MAC   39403.135907
# 148                                            Morocco  MAR    3058.691689
# 149                                             Monaco  MCO  173688.189360
# 150                                            Moldova  MDA    4547.059721
# 151                                         Madagascar  MDG     471.491496
# 152                                           Maldives  MDV    6924.105745
# 153                         Middle East & North Africa  MEA    6534.395623
# 154                                             Mexico  MEX    8329.271313
# 155                                   Marshall Islands  MHL    4129.850998
# 156                                      Middle income  MIC    5216.947891
# 157                                    North Macedonia  MKD    5917.262575
# 158                                               Mali  MLI     862.453019
# 159                                              Malta  MLT   27884.642827
# 160                                            Myanmar  MMR    1467.604281
# 161  Middle East & North Africa (excluding high inc...  MNA    3018.433655
# 162                                         Montenegro  MNE    7677.152226
# 163                                           Mongolia  MNG    4060.950518
# 165                                         Mozambique  MOZ     448.544281
# 166                                         Mauritania  MRT    1701.991163
# 167                                          Mauritius  MUS    8627.843157
# 168                                             Malawi  MWI     636.820537
# 169                                           Malaysia  MYS   10412.348983
# 170                                      North America  NAC   61502.095945
# 171                                            Namibia  NAM    4179.278066
# 173                                              Niger  NER     567.669892
# 174                                            Nigeria  NGA    2097.092473
# 175                                          Nicaragua  NIC    1905.261152
# 176                                        Netherlands  NLD   52397.116713
# 177                                             Norway  NOR   67329.677791
# 178                                              Nepal  NPL    1155.142854
# 179                                              Nauru  NRU   10580.268188
# 180                                        New Zealand  NZL   41441.466667
# 181                                       OECD members  OED   38218.872374
# 182                                               Oman  OMN   14485.386116
# 183                                 Other small states  OSS   11766.973739
# 184                                           Pakistan  PAK    1188.859757
# 185                                             Panama  PAN   12509.835290
# 186                                               Peru  PER    6126.874540
# 187                                        Philippines  PHL    3298.829586
# 188                                              Palau  PLW   14243.864692
# 189                                   Papua New Guinea  PNG    2757.217530
# 190                                             Poland  POL   15720.994664
# 191                           Pre-demographic dividend  PRE    1332.049211
# 192                                        Puerto Rico  PRI   32290.921136
# 194                                           Portugal  PRT   22176.296712
# 195                                           Paraguay  PRY    5001.072760
# 196                                 West Bank and Gaza  PSE    3239.731108
# 197                        Pacific island small states  PSS    3768.543357
# 198                          Post-demographic dividend  PST   44475.189167
# 200                                              Qatar  QAT   50124.385936
# 201                                            Romania  ROU   12896.088621
# 202                                 Russian Federation  RUS   10126.721794
# 203                                             Rwanda  RWA     797.855521
# 204                                         South Asia  SAS    1823.712912
# 205                                       Saudi Arabia  SAU   20110.316192
# 206                                              Sudan  SDN     486.418816
# 207                                            Senegal  SEN    1471.830962
# 208                                          Singapore  SGP   59797.752180
# 209                                    Solomon Islands  SLB    2250.601164
# 210                                       Sierra Leone  SLE     509.376594
# 211                                        El Salvador  SLV    3798.636521
# 213                                            Somalia  SOM     438.255166
# 214                                             Serbia  SRB    7720.510572
# 215         Sub-Saharan Africa (excluding high income)  SSA    1500.349997
# 217                                 Sub-Saharan Africa  SSF    1501.152921
# 218                                       Small states  SST   10770.589778
# 219                              Sao Tome and Principe  STP    2157.840446
# 220                                           Suriname  SUR    4916.605666
# 221                                           Slovakia  SVK   19266.513574
# 222                                           Slovenia  SVN   25517.330665
# 223                                             Sweden  SWE   52274.408787
# 224                                           Eswatini  SWZ    3424.282212
# 226                                         Seychelles  SYC   10764.420422
# 228                           Turks and Caicos Islands  TCA   23879.926649
# 229                                               Chad  TCD     659.270045
# 230         East Asia & Pacific (IDA & IBRD countries)  TEA    8346.038810
# 231       Europe & Central Asia (IDA & IBRD countries)  TEC    8387.390693
# 232                                               Togo  TGO     914.950792
# 233                                           Thailand  THA    7186.874092
# 234                                         Tajikistan  TJK     859.137961
# 236  Latin America & the Caribbean (IDA & IBRD coun...  TLA    7035.753075
# 237                                        Timor-Leste  TLS    1442.730738
# 238  Middle East & North Africa (IDA & IBRD countries)  TMN    3015.703551
# 239                                              Tonga  TON    4624.823449
# 240                            South Asia (IDA & IBRD)  TSA    1823.712912
# 241          Sub-Saharan Africa (IDA & IBRD countries)  TSS    1501.152921
# 242                                Trinidad and Tobago  TTO   15425.635109
# 243                                            Tunisia  TUN    3521.591948
# 244                                             Turkey  TUR    8536.433320
# 245                                             Tuvalu  TUV    4143.109753
# 246                                           Tanzania  TZA    1076.469706
# 247                                             Uganda  UGA     822.027682
# 248                                            Ukraine  UKR    3724.938437
# 249                                Upper middle income  UMC    9177.840437
# 250                                            Uruguay  URY   15438.411666
# 251                                      United States  USA   63593.443621
# 252                                         Uzbekistan  UZB    1750.697113
# 253                     St. Vincent and the Grenadines  VCT    7278.016297
# 257                                            Vietnam  VNM    2785.724161
# 258                                            Vanuatu  VUT    2870.089300
# 259                                              World  WLD   10918.722834
# 260                                              Samoa  WSM    4067.843459
# 261                                             Kosovo  XKX    4346.637931
# 263                                       South Africa  ZAF    5655.867654
# 264                                             Zambia  ZMB     985.132436
# 265                                           Zimbabwe  ZWE    1214.509820

# %%
gdp_country_set = set(gdp_2018_data['나라'].unique())
gdp_country_set
# Out:
# {'Afghanistan',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Euro area',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'Fiji',
#  'Finland',
#  'Fragile and conflict affected situations',
#  'France',
#  'Gabon',
#  'Gambia, The',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran, Islamic Rep.',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Latvia',
#  'Least developed countries: UN classification',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Low & middle income',
#  'Low income',
#  'Lower middle income',
#  'Luxembourg',
#  'Macau',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia, Fed. Sts.',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle income',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North America',
#  'North Macedonia',
#  'Norway',
#  'OECD members',
#  'Oman',
#  'Other small states',
#  'Pacific island small states',
#  'Pakistan',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Post-demographic dividend',
#  'Pre-demographic dividend',
#  'Puerto Rico',
#  'Qatar',
#  'Republic of Korea',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Samoa',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Small states',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Upper middle income',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vietnam',
#  'West Bank and Gaza',
#  'World',
#  'Zambia',
#  'Zimbabwe'}

# %% [markdown]
# ###  2. PISA 2018 데이터와 비교

# %% [markdown]
# - PISA의 전처리는 다른 파일에서 작성했고 해당 결과를 `pisa_2018.csv` 파일로 가져와서 사용합니다.

# %%
# PISA 2018 데이터에 있는 국가 리스트를 추출해 GDP 값이 존재하는 국가들과 비교합니다.
pisa_2018_data = pisa_2018
pisa_2018_data = pisa_2018_data.set_index('Unnamed: 0').reset_index(drop=True)
pisa_country_set = set(pisa_2018_data['Country'].unique())

# %%
common_country = pisa_country_set & gdp_country_set
common_country
# Out:
# {'Albania',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kosovo',
#  'Latvia',
#  'Lebanon',
#  'Lithuania',
#  'Luxembourg',
#  'Macau',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Moldova',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'North Macedonia',
#  'Norway',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Republic of Korea',
#  'Romania',
#  'Russian Federation',
#  'Saudi Arabia',
#  'Serbia',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'Turkey',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Vietnam'}

# %%
# 공통 국가를 기준으로 gdp, pisa 데이터에서 추출

gdp_2018_data = gdp_2018_data[gdp_2018_data['나라'].isin(common_country)].sort_values(by='나라').reset_index(drop=True)
pisa_2018_data = pisa_2018_data[pisa_2018_data['Country'].isin(common_country)].sort_values(by='Country').reset_index(drop=True)

# %%
# 두 데이터를 나라 순으로 정렬하여 합칩니다. 
pisa_gdp_2018 = pd.concat([gdp_2018_data, pisa_2018_data.loc[:, ['Score', 'Rank']]],  axis=1)
pisa_gdp_2018 = pisa_gdp_2018.rename(columns={'Score': 'PISA 점수', 'Rank': 'PISA 순위'})
pisa_gdp_2018
# Out:
#                         나라 나라코드        1인당 GDP  PISA 점수  PISA 순위
# 0                  Albania  ALB    5246.292306    405.0     62.0
# 1                Argentina  ARG    8579.017773    402.0     64.0
# 2                Australia  AUS   51692.842748    503.0     17.0
# 3                  Austria  AUT   48586.801321    484.0     28.0
# 4               Azerbaijan  AZE    4221.407478    389.0     69.0
# 5                  Belarus  BLR    6424.152176    474.0     36.0
# 6                  Belgium  BEL   45159.348223    493.0     23.0
# 7   Bosnia and Herzegovina  BIH    6079.738285    403.0     63.0
# 8                   Brazil  BRA    6796.844542    413.0     58.0
# 9                   Brunei  BRN   27442.953828    408.0     60.0
# 10                Bulgaria  BGR   10079.203381    420.0     54.0
# 11                  Canada  CAN   43294.648163    520.0      6.0
# 12                   Chile  CHL   13231.704207    452.0     44.0
# 13                   China  CHN   10434.775187    555.0      1.0
# 14                Colombia  COL    5334.556042    412.0     59.0
# 15              Costa Rica  CRI   12140.854155    426.0     50.0
# 16                 Croatia  HRV   14134.162681    479.0     30.0
# 17                  Cyprus  CYP   27527.845306    424.0     51.0
# 18          Czech Republic  CZE   22931.274598    490.0     26.0
# 19                 Denmark  DNK   61063.316430    501.0     19.0
# 20      Dominican Republic  DOM    7268.196910    342.0     77.0
# 21                 Estonia  EST   23027.026996    523.0      5.0
# 22                 Finland  FIN   48744.988127    520.0      6.0
# 23                  France  FRA   39030.360371    493.0     23.0
# 24                 Georgia  GEO    4266.690795    380.0     71.0
# 25                 Germany  DEU   46208.429472    498.0     21.0
# 26                  Greece  GRC   17622.541003    457.0     43.0
# 27               Hong Kong  HKG   46323.863442    524.0      4.0
# 28                 Hungary  HUN   15980.740890    476.0     33.0
# 29                 Iceland  ISL   59270.180051    474.0     36.0
# 30               Indonesia  IDN    3869.588427    371.0     73.0
# 31                 Ireland  IRL   85267.764744    518.0      8.0
# 32                  Israel  ISR   44168.943636    470.0     38.0
# 33                   Italy  ITA   31714.220947    476.0     33.0
# 34                   Japan  JPN   40193.252445    504.0     15.0
# 35                  Jordan  JOR    4282.765825    419.0     56.0
# 36              Kazakhstan  KAZ    9122.233430    387.0     70.0
# 37                  Kosovo  XKX    4346.637931    353.0     75.0
# 38                  Latvia  LVA   17726.252935    479.0     30.0
# 39                 Lebanon  LBN    4649.547646    353.0     75.0
# 40               Lithuania  LTU   20233.641348    476.0     33.0
# 41              Luxembourg  LUX  116014.602497    470.0     38.0
# 42                   Macau  MAC   39403.135907    525.0      3.0
# 43                Malaysia  MYS   10412.348983    415.0     57.0
# 44                   Malta  MLT   27884.642827    448.0     45.0
# 45                  Mexico  MEX    8329.271313    420.0     54.0
# 46                 Moldova  MDA    4547.059721    424.0     51.0
# 47              Montenegro  MNE    7677.152226    421.0     53.0
# 48                 Morocco  MAR    3058.691689    359.0     74.0
# 49             Netherlands  NLD   52397.116713    485.0     27.0
# 50             New Zealand  NZL   41441.466667    506.0     11.0
# 51         North Macedonia  MKD    5917.262575    393.0     67.0
# 52                  Norway  NOR   67329.677791    499.0     20.0
# 53                  Panama  PAN   12509.835290    377.0     72.0
# 54                    Peru  PER    6126.874540    401.0     65.0
# 55             Philippines  PHL    3298.829586    340.0     78.0
# 56                  Poland  POL   15720.994664    512.0     10.0
# 57                Portugal  PRT   22176.296712    492.0     25.0
# 58                   Qatar  QAT   50124.385936    407.0     61.0
# 59       Republic of Korea  KOR   31631.469451    514.0      9.0
# 60                 Romania  ROU   12896.088621    428.0     48.0
# 61      Russian Federation  RUS   10126.721794    479.0     30.0
# 62            Saudi Arabia  SAU   20110.316192    399.0     66.0
# 63                  Serbia  SRB    7720.510572    439.0     46.0
# 64               Singapore  SGP   59797.752180    549.0      2.0
# 65                Slovakia  SVK   19266.513574    458.0     42.0
# 66                Slovenia  SVN   25517.330665    495.0     22.0
# 67                  Sweden  SWE   52274.408787    506.0     11.0
# 68             Switzerland  CHE   87097.036450    484.0     28.0
# 69                Thailand  THA    7186.874092    393.0     67.0
# 70                  Turkey  TUR    8536.433320    466.0     40.0
# 71                 Ukraine  UKR    3724.938437    466.0     40.0
# 72    United Arab Emirates  ARE   36284.555243    432.0     47.0
# 73          United Kingdom  GBR   41059.168809    504.0     15.0
# 74           United States  USA   63593.443621    505.0     13.0
# 75                 Uruguay  URY   15438.411666    427.0     49.0
# 76                 Vietnam  VNM    2785.724161    505.0     13.0

# %% [markdown]
# ### 4. GDP와 PISA Reading Score의 관계 시각화

# %% [markdown]
# - Reading score가 높을수록 gdp에 어떤 영향을 주는지 보기 위해 `seaborn`의 `regplot`을 사용합니다.
# - 만약 그래프가 우상향 한다면 양의 상관관계를 가진다고 할 수 있습니다.
# - `scikit-learn`의 `LinearRegression` 을 한번 사용해 보겠습니다.

# %%
# 1인당 gdp와 reading Score의 관계를 확인하기 위해 Seaborn의 regplot을 그려봅니다.
# 변화를 좀더 명확하게 보기 위해 x축과 y축에 limit을 걸어줍니다.

# plt.ylim(10000, 120000)
# plt.xlim(450, 530)
sns.regplot(x = 'PISA 점수', y = '1인당 GDP', data = pisa_gdp_2018)
# Out:
# <AxesSubplot:xlabel='PISA 점수', ylabel='1인당 GDP'>

# %%
# sklearn 사용
# 선형 회귀 모델을 적용하기 위해 sklearn의 lineRegression을 사용해 보았습니다.
# 이 부분은 관련 지식 없이 간단하게 적용해본 test라고 보시면 됩니다.

line_fitter = linear_model.LinearRegression()
x = pisa_gdp_2018['PISA 점수']
y = pisa_gdp_2018['1인당 GDP']
line_fitter.fit(x.values.reshape(-1, 1), y)

print("기울기:", line_fitter.coef_)
plt.plot(x, line_fitter.predict(x.values.reshape(-1,1)))
# plt.ylim(10000, 120000)
# plt.xlim(450, 530)
sns.regplot(x = 'PISA 점수', y = '1인당 GDP', data = pisa_gdp_2018)
plt.show()
# Out:
# 기울기: [255.54298584]

# %%
pisa_gdp_2018.corr()
# Out:
#           1인당 GDP   PISA 점수   PISA 순위
# 1인당 GDP  1.000000  0.578925 -0.579101
# PISA 점수  0.578925  1.000000 -0.986068
# PISA 순위 -0.579101 -0.986068  1.000000

# %%
# sklearn 사용
# RANSAC 모델을 사용해보았습니다.

X = pisa_gdp_2018['PISA 점수']
y = pisa_gdp_2018['1인당 GDP']

ransac = linear_model.RANSACRegressor()
ransac.fit(X.values.reshape(-1, 1), y)
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

line_X = X.values.reshape(-1, 1)
line_y_ransac = ransac.predict(line_X)

print("Ransac_coef:", ransac.estimator_.coef_)
plt.plot(
    line_X,
    line_y_ransac,
    color="red",
    label="RANSAC regressor",
)
# plt.ylim(10000, 120000)
# plt.xlim(450, 530)
sns.regplot(x = 'PISA 점수', y = '1인당 GDP', data = pisa_gdp_2018)
plt.show()
# Out:
# Ransac_coef: [281.18583183]

# %% [markdown]
# ## outlier 제거 후 다시 그려보기
# - 기준:
#     - 1. IQR : 4분위수에서 (Q3 - Q1) 값, 이상치 범위는 (X < Q1 - 1.5 * IQR  || X > Q3 + 1.5 * IQR)
#     - 2. 3시그마 : 시그마는 표준편차이며 이상치 범위는 (X < 평균 - 3시그마 || X > 평균 + 3시그마)

# %%
pisa_gdp_2018[['1인당 GDP', 'PISA 점수']].describe()
# Out:
#              1인당 GDP     PISA 점수
# count      77.000000   77.000000
# mean    26014.765578  453.103896
# std     23456.162319   53.139237
# min      2785.724161  340.000000
# 25%      7268.196910  412.000000
# 50%     17622.541003  466.000000
# 75%     41441.466667  498.000000
# max    116014.602497  555.000000

# %% [markdown]
# ### Outlier 제거 - IQR 이용

# %%
fig, ax = plt.subplots(figsize=(15, 5), ncols=2)
sns.boxplot(y='1인당 GDP', data=pisa_gdp_2018, ax=ax[0], color='skyblue')
sns.boxplot(y='PISA 점수', data=pisa_gdp_2018, ax=ax[1], color='yellowgreen')
# Out:
# <AxesSubplot:ylabel='PISA 점수'>

# %%
def remove_outlier_by_IQR(df, col=[]):
    data = df
    for col_name in col:
        s = data[col_name]
        IQR = s.quantile(0.75) - s.quantile(0.25)
        data = data[s.between(s.quantile(0.25) - (1.5 * IQR), s.quantile(0.75) + (1.5 * IQR))]
    return data

data_IQR = remove_outlier_by_IQR(pisa_gdp_2018, ['1인당 GDP', 'PISA 점수'])[['나라', '1인당 GDP', 'PISA 점수']]
data_IQR.describe()
# Out:
#             1인당 GDP     PISA 점수
# count     76.000000   76.000000
# mean   24830.557197  452.881579
# std    21168.532825   53.456267
# min     2785.724161  340.000000
# 25%     7247.866205  411.000000
# 50%    16801.640946  466.000000
# 75%    41154.743273  498.250000
# max    87097.036450  555.000000

# %%
# sklearn 사용
# RANSAC 모델을 사용해보았습니다.

X = data_IQR['PISA 점수']
y = data_IQR['1인당 GDP']

ransac = linear_model.RANSACRegressor(min_samples=30)
ransac.fit(X.values.reshape(-1, 1), y)
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

line_X = X.values.reshape(-1, 1)
line_y_ransac = ransac.predict(line_X)

print("Ransac_coef:", ransac.estimator_.coef_)
plt.plot(
    line_X,
    line_y_ransac,
    color="red",
    label="RANSAC regressor",
)
# plt.ylim(10000, 120000)
# plt.xlim(450, 530)
sns.regplot(x = 'PISA 점수', y = '1인당 GDP', data = data_IQR)
plt.show()
# Out:
# Ransac_coef: [211.399401]

# %% [markdown]
# ### Outlier 제거 - 시그마 이용
# - 평균적으로 2시그마는 95%, 3시그마는 99.7% 의 데이터를 커버한다고 보면 된다.

# %%
gdp_std = pisa_gdp_2018['1인당 GDP'].std()
score_std = pisa_gdp_2018['PISA 점수'].std()

# %%
def remove_outlier_by_sigma(df, col=[], n=3):
    data = df
    for col_name in col:
        s = data[col_name]
        sigma = s.std()
        avg = s.mean()
        data = data[s.between(avg - (n * sigma), avg + (n * sigma))]
    return data

data_3sigma = remove_outlier_by_sigma(pisa_gdp_2018, ['1인당 GDP', 'PISA 점수'], 3)[['나라', '1인당 GDP', 'PISA 점수']]
data_3sigma.describe()
# Out:
#             1인당 GDP     PISA 점수
# count     76.000000   76.000000
# mean   24830.557197  452.881579
# std    21168.532825   53.456267
# min     2785.724161  340.000000
# 25%     7247.866205  411.000000
# 50%    16801.640946  466.000000
# 75%    41154.743273  498.250000
# max    87097.036450  555.000000

# %%
data_2sigma = remove_outlier_by_sigma(pisa_gdp_2018, ['1인당 GDP', 'PISA 점수'], 2)[['나라', '1인당 GDP', 'PISA 점수']]
data_2sigma.describe()
# Out:
#             1인당 GDP     PISA 점수
# count     72.000000   72.000000
# mean   23669.312768  454.652778
# std    18842.974250   50.885998
# min     2785.724161  353.000000
# 25%     7554.582692  412.750000
# 50%    16801.640946  466.000000
# 75%    40409.731536  498.250000
# max    67329.677791  555.000000

# %%
# sklearn 사용
# RANSAC 모델을 사용해보았습니다.

X = data_3sigma['PISA 점수']
y = data_3sigma['1인당 GDP']

ransac = linear_model.RANSACRegressor(min_samples=30)
ransac.fit(X.values.reshape(-1, 1), y)
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

line_X = X.values.reshape(-1, 1)
line_y_ransac = ransac.predict(line_X)

print("Ransac_coef:", ransac.estimator_.coef_)
plt.plot(
    line_X,
    line_y_ransac,
    color="red",
    label="RANSAC regressor",
)
# plt.ylim(10000, 120000)
# plt.xlim(450, 530)
sns.regplot(x = 'PISA 점수', y = '1인당 GDP', data = data_3sigma)
plt.show()
# Out:
# Ransac_coef: [224.09224678]

# %%
pisa_gdp_2018.corr()
# Out:
#           1인당 GDP   PISA 점수   PISA 순위
# 1인당 GDP  1.000000  0.578925 -0.579101
# PISA 점수  0.578925  1.000000 -0.986068
# PISA 순위 -0.579101 -0.986068  1.000000

# %%
line_X = np.squeeze(line_X)
line_X = line_X.astype('float64')
len(line_X)
# Out:
# 76

# %%
len(line_y_ransac)
# Out:
# 76

# %%
ransac_df = pd.concat([pd.Series(line_X), pd.Series(line_y_ransac)], axis=1)
ransac_df.columns = ['x', 'y']
ransac_df
# Out:
#         x             y
# 0   405.0  10130.296961
# 1   402.0   9458.020221
# 2   503.0  32091.337145
# 3   484.0  27833.584456
# 4   389.0   6544.821012
# 5   474.0  25592.661989
# 6   493.0  29850.414677
# 7   403.0   9682.112467
# 8   413.0  11923.034935
# 9   408.0  10802.573701
# 10  420.0  13491.680663
# 11  520.0  35900.905340
# 12  452.0  20662.632559
# 13  555.0  43744.133978
# 14  412.0  11698.942688
# 15  426.0  14836.234143
# 16  479.0  26713.123222
# 17  424.0  14388.049650
# 18  490.0  29178.137937
# 19  501.0  31643.152652
# 20  342.0  -3987.514586
# 21  523.0  36573.182081
# 22  520.0  35900.905340
# 23  493.0  29850.414677
# 24  380.0   4527.990791
# 25  498.0  30970.875911
# 26  457.0  21783.093793
# 27  524.0  36797.274328
# 28  476.0  26040.846482
# 29  474.0  25592.661989
# 30  371.0   2511.160570
# 31  518.0  35452.720847
# 32  470.0  24696.293001
# 33  476.0  26040.846482
# 34  504.0  32315.429392
# 35  419.0  13267.588416
# 36  387.0   6096.636519
# 37  353.0  -1522.499872
# 38  479.0  26713.123222
# 39  353.0  -1522.499872
# 40  476.0  26040.846482
# 41  525.0  37021.366574
# 42  415.0  12371.219429
# 43  448.0  19766.263572
# 44  420.0  13491.680663
# 45  424.0  14388.049650
# 46  421.0  13715.772909
# 47  359.0   -177.946391
# 48  485.0  28057.676703
# 49  506.0  32763.613886
# 50  393.0   7441.189999
# 51  499.0  31194.968158
# 52  377.0   3855.714051
# 53  401.0   9233.927974
# 54  340.0  -4435.699080
# 55  512.0  34108.167366
# 56  492.0  29626.322431
# 57  407.0  10578.481454
# 58  514.0  34556.351860
# 59  428.0  15284.418637
# 60  479.0  26713.123222
# 61  399.0   8785.743480
# 62  439.0  17749.433351
# 63  549.0  42399.580497
# 64  458.0  22007.186040
# 65  495.0  30298.599171
# 66  506.0  32763.613886
# 67  484.0  27833.584456
# 68  393.0   7441.189999
# 69  466.0  23799.924014
# 70  466.0  23799.924014
# 71  432.0  16180.787624
# 72  504.0  32315.429392
# 73  505.0  32539.521639
# 74  427.0  15060.326390
# 75  505.0  32539.521639

# %%
data_3sigma.columns = ['Country', 'GDP per Capita', 'PISA Score']
data_3sigma.to_json('pisa_gdp.json', orient = 'records')

# %%
ransac_df.to_json('ransac.json', orient = 'records')
